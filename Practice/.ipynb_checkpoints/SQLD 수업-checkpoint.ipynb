# %% [markdown]
# https://dataonair.or.kr/db-tech-reference/d-guide/sql/?pageid=5&mod=list
# 1~31 번까지

# %% [markdown]
# DB - 데이터 저장/ 조회 기능
# DBMS - 데이터 관리/복원/백업/보안 기능

# %% [markdown]
# # 1
# 2 - 시스템 구현 만을 위해 x , 나중에 개발을 위해서 쓰인다

# %% [markdown]
# # 10
# 3 - 엔터티는 두 개 이상의 인스턴스를 가져야함
# # 16
# 1 - 코드성은 별도로 구분 가능
# # 16
# - `특성`에 따른 분류 :
#      - `기본` 속성
#      - `설계` 속성 (부서명 -> 코드로 만듬)
#      - `파생` 속성 ( 원금 (기본속성) , 이자 (기본 속성), 이자율 (계산된 속성 → 파생 속성)
# # 17
# - 이미 계산되어진 속성 - > 빠른 성능
# # 25
# 가 - 유일성
# 나 - 최소성
# # 26
# 주식별자 - 사번
# 단일 식별자 - 주민등록번호..
# 내부식별자 - 사번
# 본질 식별자 - 사번
# # 29
# 4 - 식별자를 계속 빌려줄수록 식별자 관계를 고려
# ![image.png](attachment:image.png)
# 원조= 본질 식별자
